# %% [markdown]
# <a href="https://colab.research.google.com/github/AliVal1yev/ML_Internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AliVal1yev/ML_pipeline/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# My lane: Content Refresh Prioritization

# I chose the Content Refresh Prioritization lane.

# The goal is to identify pages that may need content updates before they lose more search visibility. Large websites can have thousands of pages, and manually reviewing every page is inefficient. A machine learning approach can help prioritize pages by combining different signals such as impressions, clicks, page age, and ranking information.

# This lane is useful because it focuses on supporting a real business decision: deciding which pages should be reviewed and refreshed first.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # The question
#
# ## Decision
#
# The decision is: which pages should the content team review and refresh first?
#
# ## Who acts on it?
#
# SEO specialists and content teams can use the model output to prioritize pages that may need attention.
#
# ## Action
#
# The team can update, improve, or review the pages with the highest risk scores.
#
# ## Cost of a wrong recommendation
#
# A false positive recommendation may cause the team to spend time updating pages that do not need changes.
#
# A false negative recommendation may cause important pages to continue losing search visibility without improvement.
#
# ## Why machine learning can help
#
# Page performance depends on multiple factors. Machine learning can combine different signals and find patterns that may be difficult to identify using simple manual rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # Quick look at the data
#
# The starter dataset contains 1000 pages.
#
# 350 pages are labeled as declining, which shows that there are enough examples of pages that may need attention.
#
# The average number of impressions in the last 90 days is 2450, showing that these pages have measurable search visibility.
#
# The average time since the last update is 180 days, suggesting that content freshness may be an important factor to investigate.
#
# These numbers show that content refresh prioritization is a meaningful machine learning problem.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # Careful words
#
# ## What I can claim
#
# This project can identify patterns in historical page data and create a prioritization score for pages that may need review.
#
# The model can provide decision support by helping teams decide where to focus their attention first.
#
# The results are directional and based on observed data patterns.
#
# ## What I cannot claim
#
# This model cannot prove that refreshing a page will increase rankings or traffic.
#
# It cannot predict Google's algorithm or guarantee future search performance.
#
# The model should support human decisions, not replace SEO expertise.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
